# %% [markdown]
# # Imports

# %%
import numpy as np;
import pandas as pd;

# %% [markdown]
# # Data Loads.
#
# We only need to look at the Text column.

# %%
quora_train_text = pd.read_csv('data/train.csv');
train_text = quora_train_text['question_text'];

# %% [markdown]
# # Word Embeddings
#
# We are using the 100D Glove Word Embeddings. Load into a dictionary.

# %%
embeddings_dict = {};
with open('../Embeddings/glove.6B/glove.6B.100d.txt', 'rb') as f:
    for line in f:
        values = line.split()
        word = values[0].decode('utf-8')
        vector = np.asarray(values[1:], "float32")
        embeddings_dict[word] = vector

# %% [markdown]
# Example of a word embedding

# %%
# %%time
embeddings_dict['how']
# Out:
# Wall time: 0 ns
# array([-0.23769  ,  0.59392  ,  0.58697  , -0.041788 , -0.86803  ,
#        -0.0051122, -0.4493   , -0.027985 ,  0.065674 , -0.37901  ,
#         0.31175  ,  0.20528  ,  0.431    , -0.30913  , -0.084523 ,
#         0.056902 ,  0.34704  ,  0.32332  , -0.60413  ,  0.23123  ,
#        -0.095476 , -0.50009  ,  0.024528 , -0.5819   ,  0.0075945,
#        -0.13871  , -0.26417  , -0.7827   , -0.24024  ,  0.081827 ,
#        -0.1867   ,  0.95404  , -0.057412 ,  0.0089747, -0.20492  ,
#         0.060902 , -0.018265 ,  0.3349   ,  0.2373   , -0.17605  ,
#        -0.54013  , -0.32745  , -0.088963 , -0.38417  , -1.0903   ,
#         0.17028  , -0.019269 , -0.35687  , -0.0084772, -0.81525  ,
#         0.23428  ,  0.11118  ,  0.42356  ,  1.111    , -0.35535  ,
#        -2.3889   ,  0.6203   , -0.16352  ,  1.445    ,  0.58333  ,
#        -0.22946  ,  1.4375   , -0.063997 , -0.31511  ,  1.0875   ,
#         0.39221  ,  0.73147  ,  0.57236  , -0.050781 , -0.027736 ,
#         0.41085  , -0.25076  , -0.26331  , -0.38682  ,  0.50667  ,
#        -0.178    ,  0.018334 , -0.64042  , -0.83078  ,  0.26167  ,
#         0.7191   ,  0.1505   , -0.67532  , -0.1487   , -2.1266   ,
#        -0.58562  , -0.12433  , -0.32622  , -1.0088   , -0.65506  ,
#         0.12711  ,  0.227    , -0.26423  , -0.44033  , -0.45518  ,
#        -0.28702  , -0.48125  , -0.58302  ,  0.20035  ,  0.50308  ],
#       dtype=float32)

# %% [markdown]
# # Check Coverage
#
# A function to check how many of the words in the corpus are covered by embedings.
# We want to get as close to 100% as possible.

# %%
def check_coverage(text, embeddings_dict):
    known_words, unknown_words = {}, {};
    total_known, total_unknown = 0, 0;
    
    for sentence in text:
        for word in sentence.split(' '):
            if word in known_words:
                total_known = total_known + 1;
            elif word in embeddings_dict:
                known_words[word] = embeddings_dict[word];
                total_known = total_known + 1;
            else:
                unknown_words[word] = None;
                total_unknown = total_unknown + 1;
            
    print('Total coverage of Vocabulary %.2f'%(len(known_words) / len(embeddings_dict)))
    print('Total coverage of Dataset %.2f'%(total_known / (total_known + total_unknown)));
    
    return known_words, unknown_words;

# %%
# %%time
known_words, unknown_words = check_coverage(train_text, embeddings_dict);
# Out:
# Total coverage of Vocabulary 0.18
# Total coverage of Dataset 0.71

# %% [markdown]
# Smaller Sample.
#
# Sampling 10% of the dataset for quicker testing.

# %%
rand_sample = np.random.choice(np.arange(len(quora_train_text)), int(0.10 * len(quora_train_text)))
train_text = quora_train_text.iloc[rand_sample]['question_text']

# %%
# %%time
known_words, unknown_words = check_coverage(train_text, embeddings_dict);
# Out:
# Total coverage of Vocabulary 0.08
# Total coverage of Dataset 0.71
# Wall time: 565 ms

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Step 1: Lower Casing

# %%
def lower_case(texts):
    lower_texts = texts.apply(lambda text: text.lower())
    return lower_texts;

# %%
def preprocess(texts):
    lower_texts = lower_case(texts);
    return lower_texts;

# %%
cleaned_text = preprocess(train_text);

# %%
check_coverage(cleaned_text, embeddings_dict);
# Out:
# Total coverage of Vocabulary 0.10
# Total coverage of Dataset 0.87

# %% [markdown]
# Coverage is up from 71% to 87% with lower casing.

# %% [markdown]
# ## Step 2. Unpunctuating Text

# %% [markdown]
# Find special non-alphanumeric characters that are in the dataset.

# %%
import re;

def find_special_chars(text_sentences):
    pattern = r'[^a-zA-Z0-9 ]';

    special_char_matches = set();
    for text in text_sentences:
        re_matches = re.findall(pattern, text);
        special_char_matches.update(re_matches);
    return special_char_matches;

# %%
special_char_matches = find_special_chars(train_text)
pd.DataFrame([(char, ord(char), char.encode('unicode_escape')) for char in special_char_matches]).sort_values(0)
# Out:
#       0      1           2
# 40   \n     10      b'\\n'
# 191   !     33        b'!'
# 338   "     34        b'"'
# 176   #     35        b'#'
# 328   $     36        b'$'
# 2     %     37        b'%'
# 209   &     38        b'&'
# 6     '     39        b"'"
# 146   (     40        b'('
# 136   )     41        b')'
# 261   *     42        b'*'
# 388   +     43        b'+'
# 99    ,     44        b','
# 73    -     45        b'-'
# 204   .     46        b'.'
# 12    /     47        b'/'
# 389   :     58        b':'
# 386   ;     59        b';'
# 128   <     60        b'<'
# 390   =     61        b'='
# 382   >     62        b'>'
# 80    ?     63        b'?'
# 277   @     64        b'@'
# 290   [     91        b'['
# 148   \     92     b'\\\\'
# 365   ]     93        b']'
# 286   ^     94        b'^'
# 356   _     95        b'_'
# 131   `     96        b'`'
# 21    {    123        b'{'
# 135   |    124        b'|'
# 257   }    125        b'}'
# 280   ~    126        b'~'
# 75        127    b'\\x7f'
# 25         160    b'\\xa0'
# 66    ¢    162    b'\\xa2'
# 87    £    163    b'\\xa3'
# 68    §    167    b'\\xa7'
# 132   ©    169    b'\\xa9'
# 226   «    171    b'\\xab'
# 9     ®    174    b'\\xae'
# 171   ¯    175    b'\\xaf'
# 106   °    176    b'\\xb0'
# 164   ±    177    b'\\xb1'
# 170   ²    178    b'\\xb2'
# 397   ³    179    b'\\xb3'
# 186   ´    180    b'\\xb4'
# 373   º    186    b'\\xba'
# 130   »    187    b'\\xbb'
# 428   ½    189    b'\\xbd'
# 229   ¿    191    b'\\xbf'
# 141   Á    193    b'\\xc1'
# 313   Ã    195    b'\\xc3'
# 433   Ç    199    b'\\xc7'
# 28    Î    206    b'\\xce'
# 151   Ö    214    b'\\xd6'
# 152   ×    215    b'\\xd7'
# 51    ß    223    b'\\xdf'
# 294   à    224    b'\\xe0'
# 426   á    225    b'\\xe1'
# 18    â    226    b'\\xe2'
# 198   ã    227    b'\\xe3'
# 96    ä    228    b'\\xe4'
# 395   æ    230    b'\\xe6'
# 35    ç    231    b'\\xe7'
# 46    è    232    b'\\xe8'
# 189   é    233    b'\\xe9'
# 366   ë    235    b'\\xeb'
# 47    í    237    b'\\xed'
# 321   î    238    b'\\xee'
# 50    ð    240    b'\\xf0'
# 177   ñ    241    b'\\xf1'
# 244   ò    242    b'\\xf2'
# 419   ó    243    b'\\xf3'
# 227   ö    246    b'\\xf6'
# 69    ÷    247    b'\\xf7'
# 33    ú    250    b'\\xfa'
# 190   ü    252    b'\\xfc'
# 178   Ā    256  b'\\u0100'
# 104   ā    257  b'\\u0101'
# 314   ă    259  b'\\u0103'
# 58    ć    263  b'\\u0107'
# 364   Č    268  b'\\u010c'
# 91    č    269  b'\\u010d'
# 174   đ    273  b'\\u0111'
# 78    ē    275  b'\\u0113'
# 100   ğ    287  b'\\u011f'
# 325   ī    299  b'\\u012b'
# 305   İ    304  b'\\u0130'
# 308   ı    305  b'\\u0131'
# 362   ō    333  b'\\u014d'
# 113   ř    345  b'\\u0159'
# 410   ş    351  b'\\u015f'
# 60    š    353  b'\\u0161'
# 340   ū    363  b'\\u016b'
# 19    ž    382  b'\\u017e'
# 425   ș    537  b'\\u0219'
# 402   ɖ    598  b'\\u0256'
# 43    ɹ    633  b'\\u0279'
# 269   ɾ    638  b'\\u027e'
# 399   ʒ    658  b'\\u0292'
# 387   ʻ    699  b'\\u02bb'
# 133   ˚    730  b'\\u02da'
# 157   ̃    771  b'\\u0303'
# 161   Γ    915  b'\\u0393'
# 369   Δ    916  b'\\u0394'
# 52    Σ    931  b'\\u03a3'
# 223   Φ    934  b'\\u03a6'
# 32    ά    940  b'\\u03ac'
# 408   έ    941  b'\\u03ad'
# 288   α    945  b'\\u03b1'
# 367   β    946  b'\\u03b2'
# 354   γ    947  b'\\u03b3'
# 192   δ    948  b'\\u03b4'
# 185   ε    949  b'\\u03b5'
# 411   θ    952  b'\\u03b8'
# 260   ι    953  b'\\u03b9'
# 378   μ    956  b'\\u03bc'
# 320   ν    957  b'\\u03bd'
# 70    ξ    958  b'\\u03be'
# 391   ο    959  b'\\u03bf'
# 59    π    960  b'\\u03c0'
# 404   ρ    961  b'\\u03c1'
# 312   ς    962  b'\\u03c2'
# 202   σ    963  b'\\u03c3'
# 208   τ    964  b'\\u03c4'
# 4     φ    966  b'\\u03c6'
# 275   χ    967  b'\\u03c7'
# 235   ω    969  b'\\u03c9'
# 230   ώ    974  b'\\u03ce'
# 67    ϕ    981  b'\\u03d5'
# 165   ϵ   1013  b'\\u03f5'
# 101   А   1040  b'\\u0410'
# 353   В   1042  b'\\u0412'
# 241   Д   1044  b'\\u0414'
# 27    М   1052  b'\\u041c'
# 125   О   1054  b'\\u041e'
# 181   Т   1058  b'\\u0422'
# 3     Х   1061  b'\\u0425'
# 236   а   1072  b'\\u0430'
# 42    б   1073  b'\\u0431'
# 412   г   1075  b'\\u0433'
# 65    д   1076  b'\\u0434'
# 252   е   1077  b'\\u0435'
# 379   и   1080  b'\\u0438'
# 368   й   1081  b'\\u0439'
# 108   к   1082  b'\\u043a'
# 427   л   1083  b'\\u043b'
# 103   м   1084  b'\\u043c'
# 394   н   1085  b'\\u043d'
# 162   о   1086  b'\\u043e'
# 127   п   1087  b'\\u043f'
# 430   р   1088  b'\\u0440'
# 238   с   1089  b'\\u0441'
# 11    т   1090  b'\\u0442'
# 352   ы   1099  b'\\u044b'
# 278   ь   1100  b'\\u044c'
# 110   א   1488  b'\\u05d0'
# 82    ב   1489  b'\\u05d1'
# 255   ד   1491  b'\\u05d3'
# 318   ה   1492  b'\\u05d4'
# 339   ו   1493  b'\\u05d5'
# 263   ח   1495  b'\\u05d7'
# 310   ט   1496  b'\\u05d8'
# 322   י   1497  b'\\u05d9'
# 76    כ   1499  b'\\u05db'
# 270   ל   1500  b'\\u05dc'
# 194   ם   1501  b'\\u05dd'
# 414   נ   1504  b'\\u05e0'
# 225   ר   1512  b'\\u05e8'
# 169   ש   1513  b'\\u05e9'
# 172   ת   1514  b'\\u05ea'
# 153   إ   1573  b'\\u0625'
# 213   ا   1575  b'\\u0627'
# 405   ب   1576  b'\\u0628'
# 363   ة   1577  b'\\u0629'
# 30    ت   1578  b'\\u062a'
# 45    ح   1581  b'\\u062d'
# 400   خ   1582  b'\\u062e'
# 193   د   1583  b'\\u062f'
# 415   ذ   1584  b'\\u0630'
# 64    ر   1585  b'\\u0631'
# 144   س   1587  b'\\u0633'
# 121   ش   1588  b'\\u0634'
# 111   ص   1589  b'\\u0635'
# 272   ط   1591  b'\\u0637'
# 155   ع   1593  b'\\u0639'
# 409   ف   1601  b'\\u0641'
# 140   ق   1602  b'\\u0642'
# 326   ك   1603  b'\\u0643'
# 256   ل   1604  b'\\u0644'
# 41    م   1605  b'\\u0645'
# 92    ن   1606  b'\\u0646'
# 142   ه   1607  b'\\u0647'
# 26    و   1608  b'\\u0648'
# 95    ى   1609  b'\\u0649'
# 197   ي   1610  b'\\u064a'
# 274   ٨   1640  b'\\u0668'
# 31    ک   1705  b'\\u06a9'
# 423   ँ   2305  b'\\u0901'
# 166   ं   2306  b'\\u0902'
# 1     अ   2309  b'\\u0905'
# 94    आ   2310  b'\\u0906'
# 403   इ   2311  b'\\u0907'
# 327   ई   2312  b'\\u0908'
# 268   उ   2313  b'\\u0909'
# 421   ऊ   2314  b'\\u090a'
# 357   ए   2319  b'\\u090f'
# 77    क   2325  b'\\u0915'
# 303   ख   2326  b'\\u0916'
# 147   ग   2327  b'\\u0917'
# 160   च   2330  b'\\u091a'
# 248   छ   2331  b'\\u091b'
# 377   ज   2332  b'\\u091c'
# 154   ठ   2336  b'\\u0920'
# 22    ड   2337  b'\\u0921'
# 384   त   2340  b'\\u0924'
# 371   थ   2341  b'\\u0925'
# 304   द   2342  b'\\u0926'
# 115   ध   2343  b'\\u0927'
# 231   न   2344  b'\\u0928'
# 158   प   2346  b'\\u092a'
# 434   फ   2347  b'\\u092b'
# 253   ब   2348  b'\\u092c'
# 273   भ   2349  b'\\u092d'
# 184   म   2350  b'\\u092e'
# 109   य   2351  b'\\u092f'
# 349   र   2352  b'\\u0930'
# 212   ल   2354  b'\\u0932'
# 175   व   2357  b'\\u0935'
# 342   श   2358  b'\\u0936'
# 102   स   2360  b'\\u0938'
# 219   ह   2361  b'\\u0939'
# 233   ़   2364  b'\\u093c'
# 374   ा   2366  b'\\u093e'
# 361   ि   2367  b'\\u093f'
# 296   ी   2368  b'\\u0940'
# 331   ू   2370  b'\\u0942'
# 332   े   2375  b'\\u0947'
# 221   ै   2376  b'\\u0948'
# 119   ॉ   2377  b'\\u0949'
# 381   ो   2379  b'\\u094b'
# 24    ्   2381  b'\\u094d'
# 63    ஜ   2972  b'\\u0b9c'
# 107   ட   2975  b'\\u0b9f'
# 232   ப   2986  b'\\u0baa'
# 156   ய   2991  b'\\u0baf'
# 398   ர   2992  b'\\u0bb0'
# 199   ி   3007  b'\\u0bbf'
# 293   ு   3009  b'\\u0bc1'
# 38    ோ   3019  b'\\u0bcb'
# 150   ்   3021  b'\\u0bcd'
# 250   ం   3074  b'\\u0c02'
# 62    ఌ   3084  b'\\u0c0c'
# 16    క   3093  b'\\u0c15'
# 90    గ   3095  b'\\u0c17'
# 254   చ   3098  b'\\u0c1a'
# 74    ద   3110  b'\\u0c26'
# 143   న   3112  b'\\u0c28'
# 413   బ   3116  b'\\u0c2c'
# 420   ర   3120  b'\\u0c30'
# 0     ా   3134  b'\\u0c3e'
# 375   ి   3135  b'\\u0c3f'
# 422   ీ   3136  b'\\u0c40'
# 396   ు   3137  b'\\u0c41'
# 341   ూ   3138  b'\\u0c42'
# 372   ె   3142  b'\\u0c46'
# 14    ౘ   3160  b'\\u0c58'
# 224   ౙ   3161  b'\\u0c59'
# 200   ౡ   3169  b'\\u0c61'
# 88    ค   3588  b'\\u0e04'
# 309   น   3609  b'\\u0e19'
# 350   บ   3610  b'\\u0e1a'
# 118   ร   3619  b'\\u0e23'
# 302   ะ   3632  b'\\u0e30'
# 93    ั   3633  b'\\u0e31'
# 196   ่   3656  b'\\u0e48'
# 122   Ḥ   7716  b'\\u1e24'
# 188   ầ   7847  b'\\u1ea7'
# 407   ệ   7879  b'\\u1ec7'
# 346   ồ   7891  b'\\u1ed3'
# 183   ὔ   8020  b'\\u1f54'
# 145   Ὠ   8040  b'\\u1f68'
# 242   ὰ   8048  b'\\u1f70'
# 359   ​   8203  b'\\u200b'
# 431   ‌   8204  b'\\u200c'
# 211   –   8211  b'\\u2013'
# 343   —   8212  b'\\u2014'
# 276   ‘   8216  b'\\u2018'
# 179   ’   8217  b'\\u2019'
# 124   “   8220  b'\\u201c'
# 222   ”   8221  b'\\u201d'
# 401   •   8226  b'\\u2022'
# 53    …   8230  b'\\u2026'
# 89    ‪   8234  b'\\u202a'
# 149   ‬   8236  b'\\u202c'
# 97    ′   8242  b'\\u2032'
# 7     ⁿ   8319  b'\\u207f'
# 247   ₂   8322  b'\\u2082'
# 56    ₃   8323  b'\\u2083'
# 36    ₙ   8345  b'\\u2099'
# 258   €   8364  b'\\u20ac'
# 54    ₹   8377  b'\\u20b9'
# 251   ℃   8451  b'\\u2103'
# 358   ℅   8453  b'\\u2105'
# 285   ℕ   8469  b'\\u2115'
# 214   ™   8482  b'\\u2122'
# 279   ⅓   8531  b'\\u2153'
# 306   ⅔   8532  b'\\u2154'
# 315   →   8594  b'\\u2192'
# 234   ∆   8710  b'\\u2206'
# 383   ∑   8721  b'\\u2211'
# 265   −   8722  b'\\u2212'
# 17    ∖   8726  b'\\u2216'
# 117   ∘   8728  b'\\u2218'
# 116   √   8730  b'\\u221a'
# 348   ∞   8734  b'\\u221e'
# 139   ∫   8747  b'\\u222b'
# 262   ∴   8756  b'\\u2234'
# 206   ≠   8800  b'\\u2260'
# 246   ≡   8801  b'\\u2261'
# 393   ⊥   8869  b'\\u22a5'
# 259   ◦   9702  b'\\u25e6'
# 281   ☁   9729  b'\\u2601'
# 324   ⟨  10216  b'\\u27e8'
# 299   ⟩  10217  b'\\u27e9'
# 249   ⦁  10625  b'\\u2981'
# 370   。  12290  b'\\u3002'
# 237   し  12375  b'\\u3057'
# 264   ア  12450  b'\\u30a2'
# 15    イ  12452  b'\\u30a4'
# 57    ク  12463  b'\\u30af'
# 376   ジ  12472  b'\\u30b8'
# 83    ダ  12480  b'\\u30c0'
# 13    ブ  12502  b'\\u30d6'
# 418   レ  12524  b'\\u30ec'
# 228   ン  12531  b'\\u30f3'
# 180   ・  12539  b'\\u30fb'
# 34    ー  12540  b'\\u30fc'
# 138   ㏑  13265  b'\\u33d1'
# 424   ㏒  13266  b'\\u33d2'
# 173   一  19968  b'\\u4e00'
# 159   不  19981  b'\\u4e0d'
# 317   中  20013  b'\\u4e2d'
# 432   为  20026  b'\\u4e3a'
# 282   也  20063  b'\\u4e5f'
# 163   乡  20065  b'\\u4e61'
# 300   书  20070  b'\\u4e66'
# 334   乳  20083  b'\\u4e73'
# 137   了  20102  b'\\u4e86'
# 123   人  20154  b'\\u4eba'
# 20    以  20197  b'\\u4ee5'
# 23    低  20302  b'\\u4f4e'
# 245   依  20381  b'\\u4f9d'
# 429   僧  20711  b'\\u50e7'
# 201   入  20837  b'\\u5165'
# 271   判  21028  b'\\u5224'
# 48    华  21326  b'\\u534e'
# 167   口  21475  b'\\u53e3'
# 79    名  21517  b'\\u540d'
# 239   味  21619  b'\\u5473'
# 187   啊  21834  b'\\u554a'
# 283   啧  21863  b'\\u5567'
# 337   嘉  22025  b'\\u5609'
# 81    国  22269  b'\\u56fd'
# 323   地  22320  b'\\u5730'
# 168   坑  22353  b'\\u5751'
# 5     奇  22855  b'\\u5947'
# 295   女  22899  b'\\u5973'
# 72    定  23450  b'\\u5b9a'
# 319   宝  23453  b'\\u5b9d'
# 85    家  23478  b'\\u5bb6'
# 344   对  23545  b'\\u5bf9'
# 355   就  23601  b'\\u5c31'
# 205   师  24072  b'\\u5e08'
# 182   彪  24426  b'\\u5f6a'
# 284   您  24744  b'\\u60a8'
# 307   批  25209  b'\\u6279'
# 335   据  25454  b'\\u636e'
# 297   故  25925  b'\\u6545'
# 240   文  25991  b'\\u6587'
# 417   方  26041  b'\\u65b9'
# 311   杨  26472  b'\\u6768'
# 385   林  26519  b'\\u6797'
# 71    柴  26612  b'\\u67f4'
# 44    棍  26829  b'\\u68cd'
# 39    欢  27426  b'\\u6b22'
# 267   此  27492  b'\\u6b64'
# 29    步  27493  b'\\u6b65'
# 10    民  27665  b'\\u6c11'
# 114   汤  27748  b'\\u6c64'
# 37    法  27861  b'\\u6cd5'
# 289   泳  27891  b'\\u6cf3'
# 292   游  28216  b'\\u6e38'
# 105   滢  28386  b'\\u6ee2'
# 266   特  29305  b'\\u7279'
# 287   琳  29747  b'\\u7433'
# 216   生  29983  b'\\u751f'
# 316   番  30058  b'\\u756a'
# 120   皎  30350  b'\\u768e'
# 243   盖  30422  b'\\u76d6'
# 134   眞  30494  b'\\u771e'
# 195   端  31471  b'\\u7aef'
# 347   红  32418  b'\\u7ea2'
# 330   罢  32610  b'\\u7f62'
# 8     要  35201  b'\\u8981'
# 291   見  35211  b'\\u898b'
# 301   言  35328  b'\\u8a00'
# 351   跑  36305  b'\\u8dd1'
# 360   迎  36814  b'\\u8fce'
# 98    这  36825  b'\\u8fd9'
# 55    逃  36867  b'\\u9003'
# 207   道  36947  b'\\u9053'
# 220   郑  37073  b'\\u90d1'
# 203   非  38750  b'\\u975e'
# 217   風  39080  b'\\u98a8'
# 49    魔  39764  b'\\u9b54'
# 380   鸡  40481  b'\\u9e21'
# 392   것  44163  b'\\uac83'
# 112   다  45796  b'\\ub2e4'
# 86    애  50528  b'\\uc560'
# 215   어  50612  b'\\uc5b4'
# 336   에  50640  b'\\uc5d0'
# 329   오  50724  b'\\uc624'
# 406   이  51060  b'\\uc774'
# 333   하  54616  b'\\ud558'
# 126   한  54620  b'\\ud55c'
# 84    할  54624  b'\\ud560'
# 298   했  54664  b'\\ud588'
# 210   ﷺ  65018  b'\\ufdfa'
# 416   ️  65039  b'\\ufe0f'
# 129   ﻿  65279  b'\\ufeff'
# 345   ）  65289  b'\\uff09'
# 61    ，  65292  b'\\uff0c'
# 218   ？  65311  b'\\uff1f'

# %% [markdown]
# There are a lot of Asian and Cyrrylic characters. Since we don't have embeddings for those, we can filter them out.

# %%
eastasian_re_match = r'[\u30a2-\ud588]+';
num_nonenglish_sentences = 0;
for text in train_text:
    re_matches = re.findall(eastasian_re_match, text);
    if len(re_matches) > 0:
        num_nonenglish_sentences = num_nonenglish_sentences + 1;
num_nonenglish_sentences
# Out:
# 26

# %%
southasian_re_match = r'[\u05ea-\ude48]+'
for text in train_text:
    re_matches = re.findall(southasian_re_match, text);
    if len(re_matches) > 0:
        num_nonenglish_sentences = num_nonenglish_sentences + 1;
num_nonenglish_sentences
# Out:
# 2390

# %%
cyrrylic_re_match = r'[\u0400-\u04ff]+';
for text in train_text:
    re_matches = re.findall(cyrrylic_re_match, text);
    if len(re_matches) > 0:
        num_nonenglish_sentences = num_nonenglish_sentences + 1;
num_nonenglish_sentences
# Out:
# 2395

# %%
special_char_matches = find_special_chars(filtered_train_text)
pd.options.display.max_rows = 435;
pd.DataFrame([(char, ord(char), char.encode('unicode_escape')) for char in special_char_matches]).sort_values(0)[0].values
# Out:
# array(['\n', '!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',',
#        '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']',
#        '^', '_', '`', '{', '|', '}', '~', '\x7f', '\xa0', '¢', '£', '§',
#        '©', '«', '®', '¯', '°', '±', '²', '³', '´', 'º', '»', '½', '¿',
#        'Á', 'Ã', 'Ç', 'Î', 'Ö', '×', 'ß', 'à', 'á', 'â', 'ã', 'ä', 'æ',
#        'ç', 'è', 'é', 'ë', 'í', 'î', 'ð', 'ñ', 'ò', 'ó', 'ö', '÷', 'ú',
#        'ü', 'Ā', 'ā', 'ă', 'ć', 'Č', 'č', 'ğ', 'ī', 'İ', 'ı', 'ō', 'ř',
#        'ş', 'š', 'ū', 'ž', 'ș', 'ɖ', 'ɾ', 'ʒ', 'ʻ', '˚', '̃', 'Δ', 'Σ',
#        'Φ', 'ά', 'α', 'δ', 'θ', 'ι', 'μ', 'ξ', 'ο', 'π', 'ρ', 'σ', 'χ',
#        'ω', 'ϵ', 'ח', 'ר', 'ﷺ', '️', '\ufeff', '，', '？'], dtype=object)

# %% [markdown]
# The special character set is much smaller now (although it must be remembered we are only using 10% of the dataset).
#
# From the above list, we can separate out ones we want to keep and could be useful, such as greek charcters.

# %%
replacing_chars_map = {'\n' : "",
                       '"' : '"',
                       "'" : "'",
                       '`' : "'",
                       '´' : "'",
                       '\x7f' : "",
                       '\xa0' : "",
                       'ș' : "cedillia",
                       'ʒ' : "ezh",
                       'ʻ' : "'",
                       '˚' : "degree", 
                        "α" : "alpha",
                        "β" : "beta",
                        "γ" : "gamma",
                        "Γ" : "gamma",
                        "δ" : "delta",
                        "Δ" : "delta",
                        "ϵ" : "epsilon",
                        "ζ" : "zeta",
                        "η" : "eta",
                        "θ" : "theta",
                        "Θ" : "theta",
                        "ι" : "iota",
                        "λ" : "lambda",
                        "Λ" : "lambda",
                        "μ" : "mu",
                        "ξ" : "xi",
                        "Ξ" : "xi",
                        "π" : "pi",
                        "Π" : "pi",
                        "ρ" : "rho",
                        "σ" : "sigma",
                        "Σ" : "sigma",
                        "τ" : "tau",
                        "υ" : "upsilon",
                        "ϒ" : "upsilon",
                        "ϕ" : "phi",
                        "Φ" : "phi",
                        "χ" : "chi",
                        "X" : "chi",
                        "ψ" : "psi",
                        "Ψ" : "psi",
                        "ω" : "omega",
                        "Ω" : "omega",
                       'ﷺ' : "",
                       "ר" : "resh",
                       "ח" : "heth",
                       '️' : "",
                       '\ufeff' : "",
                       '，' : ",",
                       '？' : "?",
                       '¿' : "",
                       '?' : "",
                       '"' : "",
                       ',' : ","
                      }

# %% [markdown]
# And ones we do do not need, and can remove entirely.

# %%
special_repl =  r'[!#\$%&\(\)\*\+,-\.\:;<>\?@\[\\\]\^_\{\|\}\~¢’‘…′–“”£\§©«\®¯°±²³º»½¿\/\=]';

# %%
filtered_train_text = filtered_train_text.apply(lambda text: re.sub(special_repl, "", text));

# %%
special_char_matches = find_special_chars(filtered_train_text)
pd.options.display.max_rows = 435;
pd.DataFrame([(char, ord(char), char.encode('unicode_escape')) for char in special_char_matches]).sort_values(0)[0].values
# Out:
# array(['\n', '"', "'", '`', '\x7f', '\xa0', '´', 'Á', 'Ã', 'Ç', 'Î', 'Ö',
#        '×', 'ß', 'à', 'á', 'â', 'ã', 'ä', 'æ', 'ç', 'è', 'é', 'ë', 'í',
#        'î', 'ð', 'ñ', 'ò', 'ó', 'ö', '÷', 'ú', 'ü', 'Ā', 'ā', 'ă', 'ć',
#        'Č', 'č', 'ğ', 'ī', 'İ', 'ı', 'ō', 'ř', 'ş', 'š', 'ū', 'ž', 'ș',
#        'ɖ', 'ɾ', 'ʒ', 'ʻ', '˚', '̃', 'Δ', 'Σ', 'Φ', 'ά', 'α', 'δ', 'θ',
#        'ι', 'μ', 'ξ', 'ο', 'π', 'ρ', 'σ', 'χ', 'ω', 'ϵ', 'ח', 'ר', 'ﷺ',
#        '️', '\ufeff', '，', '？'], dtype=object)

# %% [markdown]
# Function to replace instances of character intances from a map.

# %%
def replace_with_map(main_text, repl_map):
    for key in repl_map.keys():
        main_text = main_text.replace(key, repl_map[key])
    return main_text;

# %%
filtered_train_text = filtered_train_text.apply(lambda text: replace_with_map(text, replacing_chars_map))

# %%
special_char_matches = find_special_chars(filtered_train_text)
pd.options.display.max_rows = 435;
pd.DataFrame([(char, ord(char), char.encode('unicode_escape')) for char in special_char_matches]).sort_values(0)[0].values
# Out:
# array(["'", ',', 'Á', 'Ã', 'Ç', 'Î', 'Ö', '×', 'ß', 'à', 'á', 'â', 'ã',
#        'ä', 'æ', 'ç', 'è', 'é', 'ë', 'í', 'î', 'ð', 'ñ', 'ò', 'ó', 'ö',
#        '÷', 'ú', 'ü', 'Ā', 'ā', 'ă', 'ć', 'Č', 'č', 'ğ', 'ī', 'İ', 'ı',
#        'ō', 'ř', 'ş', 'š', 'ū', 'ž', 'ɖ', 'ɾ', '̃'], dtype=object)

# %% [markdown]
# Finally, using the above steps, we can write a final method to replace all special charcters.
#
# We will:
# 1. filter out all asian (east and southern) characters
# 2. filter out all cyryllic characters
# 3. remove unneccessary punctuation
# 4. replace additional characters, including greek letters and different styles of quotations

# %%
def filter_specialchars(texts):
    filtered_train_text = texts.apply(lambda text: re.sub(special_repl, "", text));
    filtered_train_text = filtered_train_text.apply(lambda text: replace_with_map(text, replacing_chars_map))

    filtered_train_text = filtered_train_text[~filtered_train_text.str.contains(eastasian_re_match)]
    filtered_train_text = filtered_train_text[~filtered_train_text.str.contains(southasian_re_match)]
    filtered_train_text = filtered_train_text[~filtered_train_text.str.contains(cyrrylic_re_match)]
            
    return filtered_train_text;

# %% [markdown]
# Update Preprocess step

# %%
def preprocess(texts):
    lower_texts = lower_case(texts);
    unpunctuated_texts = filter_specialchars(lower_texts)
    return unpunctuated_texts;

# %%
cleaned_text = preprocess(train_text)

# %% [markdown]
# Our Coverage went from 87% to 98% after fixing special characters.

# %%
# %%time
_, _ = check_coverage(cleaned_text, embeddings_dict)
# Out:
# Total coverage of Vocabulary 0.11
# Total coverage of Dataset 0.98
# Wall time: 412 ms

# %% [markdown]
# # Step 3. Contractions

# %% [markdown]
# In the next step, we will replace all contractions with their expanded versions. We will use the following dictionary.

# %%
contractions = { 
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he had",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"i'd": "i had",
"i'd've": "i would have",
"i'll": "i will",
"i'll've": "i will have",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it had",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she had",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so is",
"that'd": "that had",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there had",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they had",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we had",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": " what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you had",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have"
}

# %% [markdown]
# We can reuse the replace map method from above.

# %%
def correct_contractions(texts):
    corrected_text = texts.apply(lambda text: replace_with_map(text, contractions))
    return corrected_text;

# %% [markdown]
# Updated preprocess step to include contractions

# %%
def preprocess(texts):
    lower_texts = lower_case(texts);
    unpunctuated_texts = filter_specialchars(lower_texts)
    expanded_texts = correct_contractions(unpunctuated_texts)
    return expanded_texts;

# %% [markdown]
# Coverage stayed at 98%, which means that the difference is negligible.

# %%
cleaned_text = preprocess(train_text)
_, unknown_words = check_coverage(cleaned_text, embeddings_dict)
# Out:
# Total coverage of Vocabulary 0.11
# Total coverage of Dataset 0.98

# %% [markdown]
# Let's look at a few of the unknown words to see what else can we fix.

# %%
unknown_words
# Out:
# {'infp': None,
#  'cruency': None,
#  "person's": None,
#  'hisher': None,
#  'handwtiting': None,
#  '': None,
#  "thiel's": None,
#  'pferdestarke': None,
#  'cotenant': None,
#  '18yearold': None,
#  '17yearold': None,
#  'microperforate': None,
#  "kejriwal's": None,
#  'ccurse': None,
#  "jobs'": None,
#  'newdelhi': None,
#  'photogenetic': None,
#  'heshe': None,
#  'x210': None,
#  "bloomer's": None,
#  'darkskinned': None,
#  "i'm": None,
#  'sciencentific': None,
#  'directoriesto': None,
#  'selfimprovement': None,
#  'bhagavadgita': None,
#  "'water": None,
#  "level'": None,
#  "karen's": None,
#  "bangli's": None,
#  "byju's": None,
#  'ibps': None,
#  'adwordskeyword': None,
#  "man's": None,
#  '16yearold': None,
#  'babumoshai': None,
#  '18cm': None,
#  '13yearold': None,
#  'perfectionismimposter': None,
#  'doobay': None,
#  'mrtrump': None,
#  '÷7': None,
#  'hedicine': None,
#  'laravel': None,
#  'unballanced': None,
#  "today's": None,
#  'vinnytsya': None,
#  'y6': None,
#  'powerfulskilled': None,
#  'no46': None,
#  'range4': None,
#  '5090': None,
#  'xmen': None,
#  'insesitive': None,
#  'stillalive': None,
#  'renhuai': None,
#  '700am': None,
#  'criminalscrimes': None,
#  'utoo': None,
#  'neonazi': None,
#  'oppourtunities': None,
#  'nonarab': None,
#  'aplied': None,
#  'antminer': None,
#  'bitmain': None,
#  'altright': None,
#  'daybyday': None,
#  'smule': None,
#  "one's": None,
#  'moreovr': None,
#  "night's": None,
#  "nixon's": None,
#  'taperecording': None,
#  'eatingdrinking': None,
#  'allterms': None,
#  'memoryloss': None,
#  'preeching': None,
#  'uxui': None,
#  '19192023': None,
#  'cryptocurrencies': None,
#  'businessbrand': None,
#  'pastebin': None,
#  'tallyerp': None,
#  'tier3': None,
#  'octupus': None,
#  'savoretti': None,
#  'pushlegspull': None,
#  'pushpullsplit': None,
#  "i'd": None,
#  'cgst': None,
#  'igst': None,
#  'agender': None,
#  'vipparcel': None,
#  'firstclass': None,
#  'maintaning': None,
#  'draivd': None,
#  'sunrun': None,
#  "justin's": None,
#  'beliebers': None,
#  'howdifficult': None,
#  '90of': None,
#  'bholejee': None,
#  'matajee': None,
#  'comsider': None,
#  'gerenal': None,
#  'advantagesdisadvantages': None,
#  'adhdadd': None,
#  'gunwielding': None,
#  'schizoids': None,
#  'selftanning': None,
#  '49inch': None,
#  'xd80': None,
#  "spears'": None,
#  'selfteaching': None,
#  'bpocall': None,
#  'neiil': None,
#  'samudram': None,
#  'lakhadweep': None,
#  "someone's": None,
#  "individual's": None,
#  'selfesteem': None,
#  'motherinlaw': None,
#  'ilets': None,
#  "taboo's": None,
#  "else's": None,
#  '14year': None,
#  'selfaware': None,
#  'x2y24': None,
#  'x3y38': None,
#  'machedo': None,
#  'dumbwaiters': None,
#  'eindiawholesale': None,
#  "bjp's": None,
#  'energyharvesting': None,
#  'antifederalist': None,
#  'subsance': None,
#  "'fun'": None,
#  'arithmomania': None,
#  'formalmathematical': None,
#  'determinismrandomness': None,
#  '1year': None,
#  '780mgday': None,
#  "world's": None,
#  'mobiless': None,
#  'wereanimals': None,
#  'articleship': None,
#  'excasualhookup': None,
#  "chapin's": None,
#  "does'nt": None,
#  "'creative": None,
#  "enterprise'": None,
#  'councelling': None,
#  'bibletorah': None,
#  'prorussian': None,
#  'russianinfluenced': None,
#  'americagermanyfrance': None,
#  "partner's": None,
#  "kadane's": None,
#  'subarray': None,
#  "'the": None,
#  "states'": None,
#  "us'": None,
#  'feminismwhy': None,
#  'yachtmaster': None,
#  'firstlevel': None,
#  "building's": None,
#  'parnamirim': None,
#  "babu's": None,
#  'ddottheta': None,
#  'asinthetat': None,
#  'displaystyle': None,
#  'dfracdphisqrt1dfrac12sin2phi': None,
#  'condidering': None,
#  'izuku': None,
#  'midoriya': None,
#  'malegra': None,
#  '50mg': None,
#  'bootcamps': None,
#  'wifes': None,
#  'trasaction': None,
#  "mnc's": None,
#  'framewoek': None,
#  'batterypowered': None,
#  'humancarrying': None,
#  'alchohal': None,
#  'chaemical': None,
#  'contients': None,
#  'iocl': None,
#  "israel's": None,
#  'tr85': None,
#  'daeron': None,
#  'aemon': None,
#  "naerys's": None,
#  "naery's": None,
#  "personality's": None,
#  'gurvinder': None,
#  'unacademy': None,
#  'processif': None,
#  'pypy': None,
#  'ssj2fp': None,
#  'typetap': None,
#  "anderson's": None,
#  'ecuse': None,
#  'aryabhatta': None,
#  '19731974': None,
#  'httpswwwyoutubecomwatchvboeuuq3ttm': None,
#  'flipkart': None,
#  'liberalarts': None,
#  'misinject': None,
#  'feminineish': None,
#  'furuncles': None,
#  "other's": None,
#  'sanjeevini': None,
#  "buffett's": None,
#  'leftleaning': None,
#  "obama's": None,
#  'countriesand': None,
#  "'unbound": None,
#  "feet'": None,
#  "'kanshi": None,
#  "sthal'": None,
#  'apper': None,
#  'quorans': None,
#  'composersmusicians': None,
#  'baahubali': None,
#  'aavin': None,
#  'skitty': None,
#  'wailord': None,
#  'progun': None,
#  "crab's": None,
#  'seppukuhair': None,
#  "iim's": None,
#  'poputation': None,
#  'hemophobia': None,
#  "woman's": None,
#  'angellist': None,
#  'mbiology': None,
#  'doordash': None,
#  'enemie': None,
#  'ceragem': None,
#  'gonig': None,
#  '3cm': None,
#  '4cm': None,
#  'coliving': None,
#  'cyanokit': None,
#  "skywalker's": None,
#  "brown's": None,
#  'blockchain': None,
#  "men's": None,
#  'esalesoffercom': None,
#  'cadcam': None,
#  'scpcm': None,
#  'gate2018': None,
#  'allivet': None,
#  'boundries': None,
#  'bgv': None,
#  'prejoining': None,
#  'jobscareers': None,
#  'satisfiers': None,
#  '5second': None,
#  "leedskalnin's": None,
#  'upvotes': None,
#  "i've": None,
#  'holescar': None,
#  'wihout': None,
#  'growlingscreaming': None,
#  'rno2': None,
#  'pcmb': None,
#  'bipcneet': None,
#  "nordin's": None,
#  '190000': None,
#  'storiesexperiences': None,
#  'northham': None,
#  "'nose'": None,
#  'redmi': None,
#  'narccissists': None,
#  'wasis': None,
#  'probook': None,
#  'asyn': None,
#  'yesrs': None,
#  "singh's": None,
#  'onlineoffline': None,
#  'moralsstandards': None,
#  'cringy': None,
#  'greyhoundstyle': None,
#  'javadiscussioncom': None,
#  'rssbjp': None,
#  'wechat': None,
#  'chakravartin': None,
#  "asura's": None,
#  'economychanging': None,
#  "computer's": None,
#  'pitchinglaunch': None,
#  'cgle': None,
#  'nphard': None,
#  'npcomplete': None,
#  'boolks': None,
#  '4abc': None,
#  'lovelike': None,
#  'djt': None,
#  'peepee': None,
#  'titanfall': None,
#  'ghitorini': None,
#  "vancouver's": None,
#  'steemit': None,
#  'viteee': None,
#  'manchaster': None,
#  '2008crisis': None,
#  'agratala': None,
#  "'assigned'": None,
#  'lonewolf': None,
#  'provings': None,
#  'carrear': None,
#  'twentyone': None,
#  'quoran': None,
#  'thermoscope': None,
#  'antiamerican': None,
#  'antiisraeli': None,
#  'relationshipstarting': None,
#  'cryptocurrency': None,
#  'intresting': None,
#  'reactionless': None,
#  'tlwr1043nd': None,
#  'ipenz': None,
#  "college's": None,
#  'b1s1': None,
#  'dsssb': None,
#  "correspondents'": None,
#  'zentangle': None,
#  "somebody's": None,
#  'wishky': None,
#  "philippines'": None,
#  'isil': None,
#  'collegeboard': None,
#  'lucktastic': None,
#  'efficiencydriven': None,
#  'politicsdriven': None,
#  'orientating': None,
#  'paediatricsorthoradiodiagnosis': None,
#  'stresful': None,
#  'petsitting': None,
#  "owners'": None,
#  'girlwoman': None,
#  "'slut'": None,
#  "human's": None,
#  "glover's": None,
#  'epmexcel': None,
#  'ns3': None,
#  "scribd's": None,
#  'cbseneet': None,
#  'prorussia': None,
#  'capten': None,
#  'noolger': None,
#  'xoogler': None,
#  "5'5": None,
#  "master's": None,
#  'computional': None,
#  'roboteer': None,
#  "'a'": None,
#  'cardiaccardiovascular': None,
#  'wtis': None,
#  "nepal's": None,
#  'tharuhat': None,
#  'x44x38x28x4': None,
#  'jeanlouis': None,
#  'sebagh': None,
#  'disableturn': None,
#  'offdestroy': None,
#  'groccery': None,
#  'weightedknuckle': None,
#  'dysfuntiun': None,
#  'daca': None,
#  '360p': None,
#  'anskf': None,
#  "children's": None,
#  "'chummy'": None,
#  'fiitjee': None,
#  'clevertopper': None,
#  'comitting': None,
#  'prochinese': None,
#  'proprc': None,
#  "sridevi's": None,
#  'iteniary': None,
#  '3ca': None,
#  'hearingreading': None,
#  "'bhandary": None,
#  "vertica'": None,
#  'clarinetlike': None,
#  'concieve': None,
#  "pi's": None,
#  'manicurepedicure': None,
#  'artcolourextention': None,
#  '3000mgs': None,
#  'trzadone': None,
#  'offbutton': None,
#  '×89': None,
#  'anerica': None,
#  'udemy': None,
#  "'following'": None,
#  'pbuh': None,
#  "'alhamdulillah'": None,
#  'vains': None,
#  'closedminded': None,
#  'bsnonexistent': None,
#  'antimulticultural': None,
#  'reallife': None,
#  'counseladvice': None,
#  'plazzo': None,
#  'pinpassword': None,
#  'fyers': None,
#  'psats': None,
#  "google's": None,
#  'kuenyehia': None,
#  '450w': None,
#  '550w': None,
#  'himher': None,
#  'beautifull': None,
#  'robotstxt': None,
#  'ggsipu': None,
#  "hindu's": None,
#  'mathsum': None,
#  'frac14nsqrtnmath': None,
#  'rajhamundravaram': None,
#  'iranianamericans': None,
#  'commerece': None,
#  "thailand's": None,
#  'certificare': None,
#  'ultrons': None,
#  'sokovia': None,
#  'scienes': None,
#  "centre's": None,
#  'blogsvlogs': None,
#  "queen's": None,
#  "rival'": None,
#  '31325': None,
#  'integrety': None,
#  'quara': None,
#  'marriedwhat': None,
#  "'fifty": None,
#  "darker'": None,
#  "anna's": None,
#  'ultraorthodox': None,
#  'jres': None,
#  "mcdonald's": None,
#  "akiba's": None,
#  'ct680': None,
#  'pccp': None,
#  'yccp': None,
#  'selfdirected': None,
#  'manufacturersbakeries': None,
#  'sublayers': None,
#  "drucker's": None,
#  'vermicomposting': None,
#  'nixxie': None,
#  "teachercouncilman's": None,
#  'offtherailsliberal': None,
#  'digitalmarketing': None,
#  'neetiit': None,
#  'resits': None,
#  'approchable': None,
#  'brv': None,
#  "megamind's": None,
#  'iiser': None,
#  'isercvisva': None,
#  'nontaning': None,
#  'angularjs': None,
#  'blockstack': None,
#  'ethereum': None,
#  '38and41week': None,
#  "dog's": None,
#  'jarur': None,
#  'bostwana': None,
#  'choosen': None,
#  'hallreading': None,
#  'halllibraries': None,
#  'thakurli': None,
#  'centos7': None,
#  'opendkimsh': None,
#  'chmod': None,
#  'diffrent': None,
#  'iswas': None,
#  'epidata': None,
#  "elway's": None,
#  'britishstyle': None,
#  'subjectverb': None,
#  'elimanate': None,
#  'seientific': None,
#  'slavessomething': None,
#  'dharna': None,
#  'josaa': None,
#  'lowcarb': None,
#  'prereqs': None,
#  'hydrographics': None,
#  'shortterm': None,
#  'dilite': None,
#  "china's": None,
#  'icompus': None,
#  'livefr': None,
#  '850hour': None,
#  'pageview': None,
#  'b2b2c': None,
#  'iitd': None,
#  'shkuld': None,
#  'neetto': None,
#  'cromagnons': None,
#  'panregular': None,
#  '16l': None,
#  'tot300': None,
#  'hyperloop': None,
#  "driver's": None,
#  'moviepass': None,
#  "spider's": None,
#  'administratoon': None,
#  'vounteers': None,
#  'closefriends': None,
#  'rohignyas': None,
#  'recived': None,
#  'moondashcoin': None,
#  "miller's": None,
#  'leadersdirectors': None,
#  '170k': None,
#  'pinarayi': None,
#  'equilant': None,
#  'slipstreaming': None,
#  "tesla's": None,
#  'superscience': None,
#  'girlsfeel': None,
#  'nalira': None,
#  'rumaizan': None,
#  'midlleclass': None,
#  "pressure's": None,
#  'dastyari': None,
#  "mozart's": None,
#  'howwhere': None,
#  "kids'": None,
#  'starsartists': None,
#  'nicmar': None,
#  'www10digicom': None,
#  "others'": None,
#  "50's": None,
#  'bookingcom': None,
#  'homosphere': None,
#  "anorexics'": None,
#  "bones'": None,
#  'fck1': None,
#  'europegermany': None,
#  "administration's": None,
#  'wealthyin': None,
#  'interestingness': None,
#  'betacarotene': None,
#  'vanet': None,
#  "brotherinlaw's": None,
#  'honer': None,
#  'binus': None,
#  'monogastric': None,
#  "bachelor's": None,
#  'headcanons': None,
#  'orietation': None,
#  'repeately': None,
#  'solo3': None,
#  'unfriend': None,
#  'mountian': None,
#  'lshtm': None,
#  'macheist': None,
#  'diogram': None,
#  'cynicscynical': None,
#  'antiwhite': None,
#  'suplyers': None,
#  'crosssection': None,
#  'kontrapunkt': None,
#  'kehrmännchen': None,
#  'supressor': None,
#  'witer': None,
#  'inhand': None,
#  'mahcet': None,
#  '44ada': None,
#  'coading': None,
#  'organsims': None,
#  'ecomonic': None,
#  'wrastling': None,
#  'gunthel': None,
#  '19481994': None,
#  'zebpay': None,
#  'moodstabilizer': None,
#  'inbound17': None,
#  'likingcommenting': None,
#  "tao's": None,
#  'achivement': None,
#  'distorded': None,
#  "god's": None,
#  'selectivepartial': None,
#  'courseapplicationsoftware': None,
#  'iima': None,
#  'v5s': None,
#  'kd50': None,
#  'phdis': None,
#  "kid's": None,
#  "'shuffled'": None,
#  'blackpink': None,
#  'intrtrovert': None,
#  'littlefinger': None,
#  'ngsguard': None,
#  'penunsula': None,
#  'pcmc': None,
#  'nobrainer': None,
#  'avansys': None,
#  'preboard': None,
#  '2345678': None,
#  'blogfacebook': None,
#  'walmartlabs': None,
#  'sprinklr': None,
#  "wein's": None,
#  'ummaya': None,
#  'keywordrevealercom': None,
#  'santra': None,
#  "son's": None,
#  'applicationsoftware': None,
#  'mobilecomputer': None,
#  'gdpr': None,
#  'amazoncom': None,
#  "curry's": None,
#  'iitb': None,
#  'uceed': None,
#  'amd10': None,
#  'trialrun': None,
#  'donot': None,
#  'ayoo3tx': None,
#  'ay006tx': None,
#  'religios': None,
#  'chanta': None,
#  "patton's": None,
#  'outofplane': None,
#  "people's": None,
#  'immigrantsrefugees': None,
#  'accesories': None,
#  'monopolyesq': None,
#  'verticaly': None,
#  'savitar': None,
#  'modikarunandhi': None,
#  'sqrt': None,
#  '1x2': None,
#  '19831987': None,
#  'jeppiaar': None,
#  'revenuegenerating': None,
#  "eye's": None,
#  'tmobile': None,
#  'germeny': None,
#  "pilot's": None,
#  'whydo': None,
#  'imaster': None,
#  'parajumbles': None,
#  'vansrvcaravan': None,
#  'antigravitational': None,
#  'businessoriented': None,
#  'codecommit': None,
#  'yureka': None,
#  'wifismoke': None,
#  'superintelligence': None,
#  'ughyer': None,
#  'artifitial': None,
#  'chritmas': None,
#  "company's": None,
#  'pythoncjava': None,
#  'backfloating': None,
#  'creamfat': None,
#  '10yearold': None,
#  'masterbation': None,
#  'mashbooh': None,
#  'nsejs': None,
#  'stateiam': None,
#  '50l': None,
#  'middleearth': None,
#  'uschina': None,
#  "usa's": None,
#  "'war": None,
#  "terror'": None,
#  'dsatm': None,
#  'whoimplemented': None,
#  "tucci's": None,
#  'pyrography': None,
#  '8tracks': None,
#  'sinthesized': None,
#  '6042': None,
#  'comedk': None,
#  'uget': None,
#  'bmsce': None,
#  'pierrejoseph': None,
#  "buc'hoz": None,
#  'aperson': None,
#  "marvel's": None,
#  'eadmit': None,
#  'caost': None,
#  'yantrik': None,
#  '022018': None,
#  'molestors': None,
#  'firstyear': None,
#  'secondyear': None,
#  "i'll": None,
#  'miralax': None,
#  'ayanavaram': None,
#  'emailsearch': None,
#  '240v': None,
#  '110v': None,
#  'nidahas': None,
#  '3gb': None,
#  'videotapping': None,
#  'chutiya': None,
#  '5years': None,
#  '5cr': None,
#  'similaritiesdifferences': None,
#  'chomba': None,
#  'bupe': None,
#  'stolenconquered': None,
#  'isobutyline': None,
#  'highfunctioning': None,
#  'intp': None,
#  'nvdia': None,
#  '970m': None,
#  'reverseharem': None,
#  'ladenbyrg': None,
#  'draanen': None,
#  "bai's": None,
#  'nationalssupporters': None,
#  'alkenynes': None,
#  "smith's": None,
#  'flvs': None,
#  'lrealpred': None,
#  'clickbank': None,
#  'giphy': None,
#  'novelpoem': None,
#  'admirial': None,
#  'yaer': None,
#  'egincluding': None,
#  "mcdaniel's": None,
#  'kaybar': None,
#  "great's": None,
#  'qhow': None,
#  'bbsr': None,
#  'scentsy': None,
#  "'why": None,
#  "most'": None,
#  'psychiatristpsychologist': None,
#  'pennis': None,
#  'jeemain': None,
#  'sppu': None,
#  '6notes': None,
#  'hashflare': None,
#  '15yrsold': None,
#  'jignesh': None,
#  'mevani': None,
#  'shehla': None,
#  'selfie': None,
#  'oldfashioned': None,
#  'twistknob': None,
#  '1940s1950s': None,
#  "hussain's": None,
#  "trump's": None,
#  'preinsulate': None,
#  'nánjīng': None,
#  'ambarella': None,
#  'dosi': None,
#  'kurnushkina': None,
#  'mastrubation': None,
#  'alfitr': None,
#  'sadaqah': None,
#  'zirconium90': None,
#  'mmfico': None,
#  'physicst': None,
#  'planetsmoons': None,
#  'daynight': None,
#  'thedificulties': None,
#  'frenchalgerian': None,
#  "'not": None,
#  "serious'": None,
#  'betelween': None,
#  'mercedesbenz': None,
#  'nitian': None,
#  'selfconfidence': None,
#  'selfdriving': None,
#  'spotifyhulu': None,
#  'aleshia': None,
#  'productservice': None,
#  'cmod': None,
#  'sarkeesian': None,
#  'trickshots': None,
#  "scott's": None,
#  'ofcomputer': None,
#  'igrua': None,
#  'angloamerican': None,
#  'complan': None,
#  'latinaox': None,
#  'experiencesambitionsdefeats': None,
#  'challengs': None,
#  'formercurrent': None,
#  'dasuya': None,
#  'jhi': None,
#  'kundli': None,
#  'sjce': None,
#  'parx': None,
#  'sebin': None,
#  'islamiphobia': None,
#  "islam's": None,
#  '8pig': None,
#  "newton's": None,
#  'pmla': None,
#  'ndps': None,
#  "''fk": None,
#  "you''": None,
#  'protrump': None,
#  'rogham': None,
#  'antid': None,
#  "texas'": None,
#  'toopen': None,
#  'mamagement': None,
#  'animalss': None,
#  'basuke': None,
#  'altcoins': None,
#  'emojis': None,
#  "'freelancer'": None,
#  'politicalpublic': None,
#  'russiaegypt': None,
#  'pa1': None,
#  'reconnective': None,
#  "ireland's": None,
#  'demonetizes': None,
#  'techinacal': None,
#  'sa2': None,
#  'ballstrike': None,
#  'byjus': None,
#  '15bpm': None,
#  'ayappa': None,
#  'picturedirector': None,
#  "'dunkirk'": None,
#  "adityanath's": None,
#  'followanyplayer': None,
#  'brexit': None,
#  'dosent': None,
#  'goodlooking': None,
#  'berrata': None,
#  'gulity': None,
#  'narcisssist': None,
#  'zerodha': None,
#  'bday': None,
#  'sportlobster': None,
#  'g4560': None,
#  '768p': None,
#  'experince': None,
#  'usamoand': None,
#  'organicultural': None,
#  'subjet': None,
#  "india's": None,
#  'iibf': None,
#  'editingrendering': None,
#  '7200u': None,
#  '940mx': None,
#  '8250u': None,
#  'dhanulti': None,
#  "5'2": None,
#  'paytm': None,
#  'accoding': None,
#  "mamiji's": None,
#  "mother's": None,
#  "sister's": None,
#  'vegatarianism': None,
#  "modi's": None,
#  'arabicspeakers': None,
#  "'arab'": None,
#  '73031': None,
#  'lowesr': None,
#  "girl's": None,
#  'begf': None,
#  'feg01': None,
#  'nahso4': None,
#  'na2so4': None,
#  'costeffective': None,
#  'magento': None,
#  'administrativ': None,
#  'retted': None,
#  "garfield's": None,
#  'howcatchem': None,
#  "gandalf's": None,
#  "iniesta's": None,
#  "brewster's": None,
#  'michrophone': None,
#  'set1': None,
#  'demotivate': None,
#  'imake': None,
#  'dealfunction': None,
#  'generalare': None,
#  'artrelated': None,
#  "asperger's": None,
#  "octavian's": None,
#  'professionarea': None,
#  'sandeshe': None,
#  'aate': None,
#  "quora's": None,
#  'opertunity': None,
#  "nederland's": None,
#  'ch3ch2coococh3': None,
#  'sachan': None,
#  'disagreementwar': None,
#  'dropshipping': None,
#  'jurisdication': None,
#  'zetsu': None,
#  'lmv': None,
#  'robocalypse': None,
#  'hastags': None,
#  'rs20000': None,
#  'nontechy': None,
#  'srcc': None,
#  'rfacebook': None,
#  'nonus': None,
#  'anxietydepression': None,
#  'tetrachoric': None,
#  'necessory': None,
#  "airtel's": None,
#  "sharp's": None,
#  'cotegery': None,
#  'cirtificate': None,
#  'nodejs': None,
#  'miningrigrentals': None,
#  'bittrex': None,
#  'purandarmahabaleshwar': None,
#  'mcom': None,
#  'amoylily': None,
#  'nonvegans': None,
#  '6723': None,
#  "veaux's": None,
#  'collegeuniversity': None,
#  'yearold': None,
#  '972100': None,
#  'numericals': None,
#  'animalstreesamoebas': None,
#  "'advanced'": None,
#  'cyberbullies': None,
#  'lifelives': None,
#  'vodeo': None,
#  'rightsaccess': None,
#  'antiauthority': None,
#  'picmix': None,
#  'parentchild': None,
#  '60l': None,
#  'dacryphilia': None,
#  'tearssobbing': None,
#  'clickbait': None,
#  'dcw': None,
#  'genuiness': None,
#  "fahnbulleh's": None,
#  'dapp': None,
#  'dapps': None,
#  '15926': None,
#  'precum': None,
#  '307307': None,
#  'dragonaut': None,
#  'fiverr': None,
#  'dxdt10x30t': None,
#  '10t': None,
#  'arrayname00': None,
#  'sloter': None,
#  '180ml': None,
#  'uiux': None,
#  '4980': None,
#  'itouch': None,
#  'womengirls': None,
#  'bitsat': None,
#  '50kt': None,
#  "kota's": None,
#  'youmail': None,
#  'pornhub': None,
#  "5'11": None,
#  "barcelona's": None,
#  'instapaper': None,
#  'workrelated': None,
#  'jjschool': None,
#  'ecoptic': None,
#  'ecept': None,
#  'visafree': None,
#  'subjectclass': None,
#  'garvebhavi': None,
#  'palya': None,
#  'reliep': None,
#  "psychopath's": None,
#  '14mth': None,
#  'rottie': None,
#  'ciansa': None,
#  'cubrt2cubrt12': None,
#  'mentalpsychologicalemotional': None,
#  'msot': None,
#  'puntucal': None,
#  'upes': None,
#  '0infinity': None,
#  'stepbystep': None,
#  'shoesize': None,
#  'qoura': None,
#  "website's": None,
#  'slovenised': None,
#  'proffessor': None,
#  'resarch': None,
#  "vodafone's": None,
#  'antisnp': None,
#  ...}

# %% [markdown]
# I see two errors we can fix here.
#
# 1. There are instances with mixed numericals and letters. For example, `780mgday` and `1year` or `tr85`.
# 2. There are contractions on nouns which aren't captured by our map, such as `israel's` and `personality's` or `glover's`.

# %% [markdown]
# We will write regular expressions for each of these, and write a method to split a word into it's proper parts:

# %%
alpha_re_match = r"([a-zA-Z]+)([0-9]+)";
numbr_re_match = r"([0-9]+)([a-zA-Z]+)";
apost_re_match = r"[a-zA-Z]+\'s";

# %%
def split_nums(text):
    new_text = [];
    for word in text.split(' '):
        alpha_match = re.match(alpha_re_match, word);
        numbr_match = re.match(numbr_re_match, word);
        apost_match = re.match(apost_re_match, word);    
        
        if alpha_match:
            new_text.append(' '.join(alpha_match.groups()));
        elif numbr_match:
            new_text.append(' '.join(numbr_match.groups()));
        elif apost_match:
            new_text.append(word.split("\'")[0] + " is");
        else:
            new_text.append(word);
    return ' '.join(new_text);

# %% [markdown]
# Update the preprocess method to include word splitting:

# %%
def preprocess(texts):
    lower_texts = lower_case(texts);
    unpunctuated_texts = filter_specialchars(lower_texts)
    expanded_texts = correct_contractions(unpunctuated_texts)
    split_text = expanded_texts.apply(lambda text: split_nums(text))
    
    return split_text;

# %%
# %%time
cleaned_text = preprocess(train_text)
_, unknown_words = check_coverage(cleaned_text, embeddings_dict)
# Out:
# Total coverage of Vocabulary 0.11
# Total coverage of Dataset 0.98
# Wall time: 8.47 s

# %% [markdown]
# Coverage did not change from 98%, but it is still good to have these preprocessing steps on the text.

# %% [markdown]
# Let's run the method on the remainder of the dataset to see how well it adjusts:

# %%
# %%time
cleaned_text = preprocess(quora_train_text['question_text'])
_, unknown_words = check_coverage(cleaned_text, embeddings_dict)
# Out:
# Total coverage of Vocabulary 0.27
# Total coverage of Dataset 0.98
# Wall time: 1min 37s

# %% [markdown]
# We still get 98% coverage of the dataset. It also shows that a larger portion of the vocabulary is also being used.

# %%
quora_train_text['cleaned_text'] = cleaned_text

# %%
quora_train_text = quora_train_text.dropna()

# %%
quora_train_text = quora_train_text.drop('question_text', axis=1)

# %%
quora_train_text.to_csv('data/cleaned_train.txt')
